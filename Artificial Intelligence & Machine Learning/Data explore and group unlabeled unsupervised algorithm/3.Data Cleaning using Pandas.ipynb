# %%
import pandas as pd
import numpy as np

# Create a dataset containing missing and duplicate values
data = {
    "Name": ["ishu", "sana", "keerthi", "veera", "tamil"],
    "Age": [20, 21, np.nan, 22, 20],
    "Marks": [85, 78, 92, np.nan, 85]
}

df = pd.DataFrame(data)

print("Original Data:")
print(df)

# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Fill missing Age with the mean age
df["Age"] = df["Age"].fillna(df["Age"].mean())

# Fill missing Marks with the mean marks
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

# Remove duplicate rows
df = df.drop_duplicates()

# Convert Age to integer
df["Age"] = df["Age"].astype(int)

print("\nCleaned Data:")
print(df)
# Out:
# Original Data:
#       Name   Age  Marks
# 0     ishu  20.0   85.0
# 1     sana  21.0   78.0
# 2  keerthi   NaN   92.0
# 3    veera  22.0    NaN
# 4    tamil  20.0   85.0
#
# Missing Values:
# Name     0
# Age      1
# Marks    1
# dtype: int64
#
# Cleaned Data:
#       Name  Age  Marks
# 0     ishu   20   85.0
# 1     sana   21   78.0
# 2  keerthi   20   92.0
# 3    veera   22   85.0
# 4    tamil   20   85.0
